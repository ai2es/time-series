# %%
from tqdm import tqdm
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data.dataset import TensorDataset, Dataset
from torch.utils.data.dataloader import DataLoader

from evidential import LinearNormalGamma, evidential_regresssion_loss

import yaml
import pandas as pd
from geckoml.data import load_data, transform_data, inv_transform_preds
from geckoml.metrics import ensembled_metrics
from collections import defaultdict

# %%
# %matplotlib inline

# %%
is_cuda = torch.cuda.is_available()
device = torch.device(torch.cuda.current_device()) if is_cuda else torch.device("cpu")
if is_cuda:
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ###  Load the gecko data

# %%
config_file = "/glade/work/schreck/repos/GECKO_OPT/dev/gecko-ml/config/toluene_agg.yml"

# %%
with open(config_file) as cf:
    conf = yaml.load(cf, Loader=yaml.FullLoader)

# %%
species = conf['species']
data_path = conf['dir_path']
aggregate_bins = conf['aggregate_bins']
input_vars = conf['input_vars']
output_vars = conf['output_vars']
tendency_cols = conf['tendency_cols']
log_trans_cols = conf['log_trans_cols']
output_path = "./"
scaler_type = conf['scaler_type']
ensemble_members = conf["ensemble_members"]
seed = conf['random_seed']

# Get the shapes of the input and output data 
input_size = len(input_vars)
output_size = len(output_vars)

start_time = 0
num_timesteps = 1439
batch_size = 8192

L1_penalty = 1.39e-5
L2_penalty = 3.49e-4

lr_patience = 3
stopping_patience = 5
learning_rate = 1e-7

# %%
data = load_data(data_path, aggregate_bins, species, input_vars, output_vars, log_trans_cols)
    
transformed_data, x_scaler, y_scaler = transform_data(
    data, 
    output_path, 
    species, 
    tendency_cols, 
    log_trans_cols,
    scaler_type, 
    output_vars, 
    train=True
)

# Batch the training data by experiment
train_in_array = transformed_data['train_in'].copy()
n_exps = len(train_in_array.index.unique(level='id'))
n_timesteps = len(train_in_array.index.unique(level='Time [s]'))
n_features = len(input_vars)
out_col_idx = train_in_array.columns.get_indexer(output_vars)
train_in_array = train_in_array.values.reshape(n_exps, n_timesteps, n_features)

# Batch the validation data by experiment
val_in_array = transformed_data['val_in'].copy()
n_exps = len(val_in_array.index.unique(level='id'))
n_timesteps = len(val_in_array.index.unique(level='Time [s]'))
val_out_col_idx = val_in_array.columns.get_indexer(output_vars)
val_in_array = val_in_array.values.reshape(n_exps, n_timesteps, n_features)

# %%
train_data = TensorDataset(
    torch.from_numpy(transformed_data["train_in"].copy().values).float(),
    torch.from_numpy(transformed_data["train_out"].copy().values).float()
)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=0)
train_iter = iter(train_loader)

valid_data = TensorDataset(
    torch.from_numpy(transformed_data["val_in"].copy().values).float(),
    torch.from_numpy(transformed_data["val_out"].copy().values).float()
)
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=False, num_workers=0)
valid_iter = iter(valid_loader)

# %% [markdown]
# ### Load an MLP model and optimizer

# %%
model = nn.Sequential(
        nn.Linear(9, 4902),
        #nn.BatchNorm1d(4902),
        #nn.LeakyReLU(),
        LinearNormalGamma(4902, 3))

input_size = 9
output_size = 3

# hidden_neurons = 4902
# dropout = 0.0

# model = nn.Sequential(
#         nn.Linear(input_size, hidden_neurons),
#         nn.BatchNorm1d(hidden_neurons),
#         #nn.Dropout(dropout),
#         nn.LeakyReLU(),
#         nn.Linear(hidden_neurons, hidden_neurons),
#         LinearNormalGamma(hidden_neurons, output_size)
#)

model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay = L2_penalty)

#lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=1e-2*learning_rate)

lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, 
        patience = lr_patience, 
        verbose = True,
        min_lr = 1.0e-13
)

# %%
results_dict = defaultdict(list)

for epoch in range(200):
    
    # Train in batch mode
    fiter = list(range(transformed_data['train_in'].shape[0] // batch_size)) #tqdm(range(transformed_data['train_in'].shape[0] // batch_size), leave=True)
    model.train()
    
    train_loss = []
    for t in fiter:

        try:
            x, y = next(train_iter)
        except StopIteration:
            train_iter = iter(train_loader)
            x, y = next(train_iter)

        loss = evidential_regresssion_loss(y, (yy.cpu() for yy in model(x.to(device))), 1e-1)
        l1_norm = sum(p.abs().sum() for p in model.parameters()).cpu()
        loss += L1_penalty * l1_norm
        train_loss.append(loss.item())

        #fiter.set_description(f"loss {np.mean(train_loss):.4f}")
        #fiter.update()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        #lr_scheduler.step()
        
    # Validate 
    model.eval()
    with torch.no_grad():
        
        # Validate in batch mode
        valid_loss = []
        fiter = list(range(transformed_data['val_in'].shape[0] // batch_size))
        for t in fiter:

            try:
                x, y = next(valid_iter)
            except StopIteration:
                valid_iter = iter(valid_loader)
                x, y = next(valid_iter)
            loss = evidential_regresssion_loss(y, (yy.cpu() for yy in model(x.to(device))), 1e-1)
            valid_loss.append(loss.item())

        
        # Validate in box mode
        box_loss = []
        box_nll = []
        
        # set up array for saving predicted results
        _in_array = torch.from_numpy(val_in_array).float()#.to(device).float()
        pred_array = np.empty((val_in_array.shape[0], num_timesteps-start_time, len(out_col_idx)))

        # use initial condition @ t = start_time and get the first prediction
        gamma, v, alpha, beta = model(_in_array[:, start_time, :].to(device))
        pred_array[:, 0, :] = gamma.cpu().numpy()
        loss = torch.nn.functional.l1_loss(_in_array[:, start_time + 1, out_col_idx], gamma.cpu()).item()
        ev_loss = evidential_regresssion_loss(
            _in_array[:, start_time + 1, out_col_idx], 
            (yy.cpu() for yy in (gamma, v, alpha, beta)), 
            1e-2
        )
        box_loss.append(loss)
        box_nll.append(ev_loss)

        # use the first prediction to get the next, and so on for num_timesteps
        for k, i in enumerate(range(start_time + 1, num_timesteps)): 
            new_input = _in_array[:, i, :]
            new_input[:, out_col_idx] = gamma.cpu()
            gamma, v, alpha, beta = model(new_input.to(device))
            pred_array[:, k+1, :] = gamma.cpu().numpy()
            if i < (num_timesteps-1):
                loss = torch.nn.functional.l1_loss(_in_array[:, i+1, out_col_idx], gamma.cpu()).item()
                ev_loss = evidential_regresssion_loss(
                    _in_array[:, start_time + 1, out_col_idx],
                    (yy.cpu() for yy in (gamma, v, alpha, beta)),
                    1e-1
                )
                box_loss.append(loss)
                box_nll.append(ev_loss)
                
        idx = transformed_data["val_out"].index
        start_time_units = sorted(list(set([x[0] for x in idx])))[start_time]
        start_time_condition = [(x[0] >= start_time_units) for x in idx]
        idx = transformed_data["val_out"][start_time_condition].index

        raw_box_preds = pd.DataFrame(
            data=pred_array.reshape(-1, len(output_vars)),
            columns=output_vars, 
            index=idx
        )

        # inverse transform 
        truth, preds = inv_transform_preds(
            raw_preds=raw_box_preds,
            truth=data['val_out'][start_time_condition],
            y_scaler=y_scaler,
            log_trans_cols=log_trans_cols,
            tendency_cols=tendency_cols)
                
        metrics = ensembled_metrics(y_true=truth,
                                    y_pred=preds,
                                    member=0,
                                    output_vars=output_vars,
                                    stability_thresh=1.0)
        mean_box_mae = metrics['mean_mae'].mean()
        unstable_exps = metrics['n_unstable'].mean()
        
    results_dict["epoch"].append(epoch)
    results_dict["train_nll"].append(np.mean(train_loss))
    results_dict["val_nll"].append(np.mean(valid_loss))
    results_dict["box_loss"].append(np.mean(box_loss))
    results_dict["box_mae"].append(mean_box_mae)
    results_dict["box_nll"].append(np.mean(box_nll))
    results_dict["n_unstable"].append(unstable_exps)
    results_dict["lr"].append(optimizer.param_groups[0]['lr'])
    
    # Save the dataframe to disk
    df = pd.DataFrame.from_dict(results_dict).reset_index()
    df.to_csv(f"gecko/training_log_01.csv", index = False)
    
    print(f'Epoch {epoch} train_nll {results_dict["train_nll"][-1]:4f}', 
          f'val_nll {results_dict["val_nll"][-1]:4f}',
          f'box_nll {results_dict["box_nll"][-1]:4f}',
          f'val_mae {results_dict["box_loss"][-1]:4f}',
          f'box_mae {results_dict["box_mae"][-1]:4f}',
          f'n_unstable {int(results_dict["n_unstable"][-1])}',
          f'lr {results_dict["lr"][-1]}'
         )

    # anneal the learning rate using just the box metric
    lr_scheduler.step(results_dict["val_nll"][-1] + results_dict["box_loss"][-1])
    
    if results_dict["box_loss"][-1] == min(results_dict["box_loss"]):
        state_dict = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': min(results_dict["box_loss"])
        }
        torch.save(state_dict, f"gecko/mlp_01.pt")
    
    # Stop training if we have not improved after X epochs
    best_epoch = [i for i,j in enumerate(results_dict["val_nll"]) if j == min(results_dict["val_nll"])][0]
    offset = epoch - best_epoch
    if offset >= stopping_patience:
        break
# Out:
# Epoch 0 train_nll 1.732970 val_nll 1.611379 box_nll 1.006082 val_mae 0.875876 box_mae 0.004293 n_unstable 5 lr 1e-07
# Epoch 1 train_nll 1.692505 val_nll 1.559691 box_nll 0.999361 val_mae 0.871233 box_mae 0.004307 n_unstable 5 lr 1e-07
# Epoch 2 train_nll 1.652803 val_nll 1.526656 box_nll 0.993075 val_mae 0.866495 box_mae 0.004324 n_unstable 5 lr 1e-07
# Epoch 3 train_nll 1.613928 val_nll 1.489665 box_nll 0.987333 val_mae 0.861704 box_mae 0.004343 n_unstable 5 lr 1e-07
# Epoch 4 train_nll 1.576150 val_nll 1.448620 box_nll 0.982486 val_mae 0.856810 box_mae 0.004367 n_unstable 5 lr 1e-07
# Epoch 5 train_nll 1.537974 val_nll 1.409170 box_nll 0.978747 val_mae 0.851819 box_mae 0.004396 n_unstable 5 lr 1e-07
# Epoch 6 train_nll 1.500532 val_nll 1.367690 box_nll 0.976311 val_mae 0.846803 box_mae 0.004431 n_unstable 5 lr 1e-07
# Epoch 7 train_nll 1.463128 val_nll 1.331572 box_nll 0.975463 val_mae 0.841914 box_mae 0.004474 n_unstable 5 lr 1e-07
# Epoch 8 train_nll 1.426416 val_nll 1.297472 box_nll 0.976363 val_mae 0.837028 box_mae 0.004524 n_unstable 5 lr 1e-07
# Epoch 9 train_nll 1.389347 val_nll 1.258127 box_nll 0.979284 val_mae 0.832197 box_mae 0.004584 n_unstable 5 lr 1e-07
# Epoch 10 train_nll 1.352853 val_nll 1.222778 box_nll 0.984570 val_mae 0.827525 box_mae 0.004658 n_unstable 5 lr 1e-07
# Epoch 11 train_nll 1.316726 val_nll 1.186908 box_nll 0.992501 val_mae 0.822954 box_mae 0.004745 n_unstable 5 lr 1e-07
# Epoch 12 train_nll 1.280319 val_nll 1.147958 box_nll 1.003473 val_mae 0.818658 box_mae 0.004854 n_unstable 5 lr 1e-07
# Epoch 13 train_nll 1.244739 val_nll 1.112935 box_nll 1.017557 val_mae 0.814590 box_mae 0.004975 n_unstable 5 lr 1e-07
# Epoch 14 train_nll 1.209079 val_nll 1.076772 box_nll 1.035146 val_mae 0.810806 box_mae 0.005125 n_unstable 5 lr 1e-07
# Epoch 15 train_nll 1.174254 val_nll 1.037615 box_nll 1.056552 val_mae 0.807363 box_mae 0.005298 n_unstable 5 lr 1e-07
# Epoch 16 train_nll 1.139644 val_nll 1.005396 box_nll 1.081885 val_mae 0.804291 box_mae 0.005503 n_unstable 5 lr 1e-07
# Epoch 17 train_nll 1.105571 val_nll 0.975506 box_nll 1.111400 val_mae 0.801605 box_mae 0.005735 n_unstable 5 lr 1e-07
# Epoch 18 train_nll 1.071932 val_nll 0.937891 box_nll 1.145259 val_mae 0.799398 box_mae 0.006004 n_unstable 5 lr 1e-07
# Epoch 19 train_nll 1.039277 val_nll 0.905643 box_nll 1.183233 val_mae 0.797564 box_mae 0.006285 n_unstable 5 lr 1e-07
# Epoch 20 train_nll 1.006714 val_nll 0.873819 box_nll 1.225731 val_mae 0.796201 box_mae 0.005072 n_unstable 6 lr 1e-07
# Epoch 21 train_nll 0.974968 val_nll 0.848138 box_nll 1.272348 val_mae 0.795247 box_mae 0.005216 n_unstable 6 lr 1e-07
# Epoch 22 train_nll 0.943632 val_nll 0.815979 box_nll 1.323343 val_mae 0.794817 box_mae 0.005379 n_unstable 6 lr 1e-07
# Epoch 23 train_nll 0.913214 val_nll 0.788561 box_nll 1.378245 val_mae 0.794591 box_mae 0.005537 n_unstable 6 lr 1e-07
# Epoch 24 train_nll 0.882781 val_nll 0.758955 box_nll 1.437165 val_mae 0.794804 box_mae 0.005704 n_unstable 6 lr 1e-07
# Epoch 25 train_nll 0.853379 val_nll 0.724115 box_nll 1.499560 val_mae 0.795118 box_mae 0.007166 n_unstable 5 lr 1e-07
# Epoch 26 train_nll 0.824126 val_nll 0.699932 box_nll 1.564999 val_mae 0.795578 box_mae 0.012057 n_unstable 1 lr 1e-07
# Epoch 27 train_nll 0.795257 val_nll 0.671733 box_nll 1.633118 val_mae 0.796132 box_mae 0.010811 n_unstable 1 lr 1e-07
# Epoch 28 train_nll 0.766995 val_nll 0.641982 box_nll 1.702820 val_mae 0.796511 box_mae 0.009692 n_unstable 1 lr 1e-07
# Epoch 29 train_nll 0.738858 val_nll 0.615160 box_nll 1.773494 val_mae 0.796352 box_mae 0.008652 n_unstable 1 lr 1e-07
# Epoch 30 train_nll 0.711494 val_nll 0.592278 box_nll 1.846221 val_mae 0.796369 box_mae 0.007874 n_unstable 1 lr 1e-07
# Epoch 31 train_nll 0.684172 val_nll 0.556744 box_nll 1.920146 val_mae 0.795979 box_mae 0.008454 n_unstable 0 lr 1e-07
# Epoch 32 train_nll 0.657101 val_nll 0.525289 box_nll 1.995121 val_mae 0.795051 box_mae 0.007646 n_unstable 0 lr 1e-07
# Epoch 33 train_nll 0.630273 val_nll 0.501800 box_nll 2.070701 val_mae 0.793681 box_mae 0.006914 n_unstable 0 lr 1e-07
# Epoch 34 train_nll 0.603939 val_nll 0.476170 box_nll 2.148531 val_mae 0.792029 box_mae 0.006346 n_unstable 0 lr 1e-07
# Epoch 35 train_nll 0.577340 val_nll 0.448961 box_nll 2.227922 val_mae 0.789786 box_mae 0.005855 n_unstable 0 lr 1e-07
# Epoch 36 train_nll 0.551372 val_nll 0.425642 box_nll 2.309937 val_mae 0.787344 box_mae 0.005465 n_unstable 0 lr 1e-07
# Epoch 37 train_nll 0.525466 val_nll 0.394807 box_nll 2.395676 val_mae 0.785058 box_mae 0.005180 n_unstable 0 lr 1e-07
# Epoch 38 train_nll 0.499586 val_nll 0.371999 box_nll 2.484035 val_mae 0.781887 box_mae 0.004919 n_unstable 0 lr 1e-07
# Epoch 39 train_nll 0.474214 val_nll 0.347002 box_nll 2.577312 val_mae 0.778858 box_mae 0.004729 n_unstable 0 lr 1e-07
# Epoch 40 train_nll 0.448657 val_nll 0.322236 box_nll 2.675438 val_mae 0.775167 box_mae 0.004576 n_unstable 0 lr 1e-07
# Epoch 41 train_nll 0.423628 val_nll 0.297797 box_nll 2.779254 val_mae 0.771056 box_mae 0.004451 n_unstable 0 lr 1e-07
# Epoch 42 train_nll 0.398602 val_nll 0.269172 box_nll 2.889555 val_mae 0.766602 box_mae 0.004352 n_unstable 0 lr 1e-07
# Epoch 43 train_nll 0.374196 val_nll 0.245959 box_nll 3.005569 val_mae 0.762005 box_mae 0.004281 n_unstable 0 lr 1e-07
# Epoch 44 train_nll 0.349943 val_nll 0.222512 box_nll 3.127865 val_mae 0.755210 box_mae 0.004196 n_unstable 0 lr 1e-07
# Epoch 45 train_nll 0.325838 val_nll 0.197938 box_nll 3.255577 val_mae 0.747569 box_mae 0.004109 n_unstable 0 lr 1e-07
# Epoch 46 train_nll 0.302554 val_nll 0.175885 box_nll 3.391816 val_mae 0.734541 box_mae 0.003990 n_unstable 0 lr 1e-07
# Epoch 47 train_nll 0.279481 val_nll 0.153814 box_nll 3.535782 val_mae 0.713202 box_mae 0.003803 n_unstable 0 lr 1e-07
# Epoch 48 train_nll 0.256786 val_nll 0.131170 box_nll 3.688148 val_mae 0.669373 box_mae 0.003476 n_unstable 0 lr 1e-07
# Epoch 49 train_nll 0.234605 val_nll 0.109393 box_nll 3.836753 val_mae 0.580099 box_mae 0.003026 n_unstable 0 lr 1e-07
# Epoch 50 train_nll 0.213336 val_nll 0.086632 box_nll 3.928529 val_mae 0.423022 box_mae 0.002421 n_unstable 0 lr 1e-07
# Epoch 51 train_nll 0.192474 val_nll 0.064243 box_nll 3.974930 val_mae 0.360399 box_mae 0.001733 n_unstable 0 lr 1e-07
# Epoch 52 train_nll 0.173114 val_nll 0.045298 box_nll 3.868294 val_mae 0.406756 box_mae 0.001942 n_unstable 0 lr 1e-07
# Epoch 53 train_nll 0.154549 val_nll 0.031153 box_nll 3.834894 val_mae 0.451954 box_mae 0.002152 n_unstable 0 lr 1e-07
# Epoch 54 train_nll 0.136692 val_nll 0.010498 box_nll 3.668448 val_mae 0.476554 box_mae 0.002301 n_unstable 0 lr 1e-07
# Epoch 55 train_nll 0.119203 val_nll -0.006318 box_nll 2.758436 val_mae 0.589911 box_mae 0.002985 n_unstable 0 lr 1e-07
# Epoch    56: reducing learning rate of group 0 to 1.0000e-08.
# Epoch 56 train_nll 0.109758 val_nll -0.009336 box_nll 2.642154 val_mae 0.608656 box_mae 0.003098 n_unstable 0 lr 1e-08
# Epoch 57 train_nll 0.108099 val_nll -0.007116 box_nll 2.528208 val_mae 0.629656 box_mae 0.003227 n_unstable 0 lr 1e-08
# Epoch 58 train_nll 0.106273 val_nll -0.009106 box_nll 2.415689 val_mae 0.652366 box_mae 0.003362 n_unstable 0 lr 1e-08
# Epoch 59 train_nll 0.104521 val_nll -0.009329 box_nll 2.319513 val_mae 0.671117 box_mae 0.003473 n_unstable 0 lr 1e-08
# Epoch 60 train_nll 0.102786 val_nll -0.010699 box_nll 2.235187 val_mae 0.689600 box_mae 0.003586 n_unstable 0 lr 1e-08
# Epoch 61 train_nll 0.101204 val_nll -0.015295 box_nll 2.193765 val_mae 0.698610 box_mae 0.003637 n_unstable 0 lr 1e-08
# Epoch 62 train_nll 0.099356 val_nll -0.014735 box_nll 2.163998 val_mae 0.706123 box_mae 0.003685 n_unstable 0 lr 1e-08
# Epoch 63 train_nll 0.097588 val_nll -0.015450 box_nll 2.141485 val_mae 0.711989 box_mae 0.003712 n_unstable 0 lr 1e-08
# Epoch 64 train_nll 0.095931 val_nll -0.017648 box_nll 2.136012 val_mae 0.713425 box_mae 0.003726 n_unstable 0 lr 1e-08
# Epoch 65 train_nll 0.094342 val_nll -0.018634 box_nll 2.141198 val_mae 0.712896 box_mae 0.003722 n_unstable 0 lr 1e-08
# Epoch 66 train_nll 0.092478 val_nll -0.018206 box_nll 2.142292 val_mae 0.713303 box_mae 0.003726 n_unstable 0 lr 1e-08
# Epoch 67 train_nll 0.090663 val_nll -0.026034 box_nll 2.137359 val_mae 0.713509 box_mae 0.003730 n_unstable 0 lr 1e-08
# Epoch 68 train_nll 0.089113 val_nll -0.031067 box_nll 2.144433 val_mae 0.714309 box_mae 0.003728 n_unstable 0 lr 1e-08
# Epoch 69 train_nll 0.087319 val_nll -0.030816 box_nll 2.141397 val_mae 0.714704 box_mae 0.003733 n_unstable 0 lr 1e-08
# Epoch 70 train_nll 0.085617 val_nll -0.031424 box_nll 2.169273 val_mae 0.709822 box_mae 0.003707 n_unstable 0 lr 1e-08
# Epoch 71 train_nll 0.083792 val_nll -0.032811 box_nll 2.140599 val_mae 0.716700 box_mae 0.003742 n_unstable 0 lr 1e-08
# Epoch 72 train_nll 0.082253 val_nll -0.031979 box_nll 2.162035 val_mae 0.711720 box_mae 0.003715 n_unstable 0 lr 1e-08
# Epoch 73 train_nll 0.080352 val_nll -0.037187 box_nll 2.166234 val_mae 0.711641 box_mae 0.003714 n_unstable 0 lr 1e-08
# Epoch 74 train_nll 0.078629 val_nll -0.037764 box_nll 2.166594 val_mae 0.712212 box_mae 0.003713 n_unstable 0 lr 1e-08
# Epoch 75 train_nll 0.077066 val_nll -0.039241 box_nll 2.167530 val_mae 0.712350 box_mae 0.003720 n_unstable 0 lr 1e-08
# Epoch 76 train_nll 0.075243 val_nll -0.040194 box_nll 2.158095 val_mae 0.714389 box_mae 0.003732 n_unstable 0 lr 1e-08
# Epoch 77 train_nll 0.073539 val_nll -0.041075 box_nll 2.193534 val_mae 0.707642 box_mae 0.003693 n_unstable 0 lr 1e-08
# Epoch 78 train_nll 0.071812 val_nll -0.045957 box_nll 2.185419 val_mae 0.710364 box_mae 0.003706 n_unstable 0 lr 1e-08
# Epoch 79 train_nll 0.070069 val_nll -0.047276 box_nll 2.194386 val_mae 0.708098 box_mae 0.003695 n_unstable 0 lr 1e-08
# Epoch 80 train_nll 0.068409 val_nll -0.048270 box_nll 2.195600 val_mae 0.708461 box_mae 0.003698 n_unstable 0 lr 1e-08
# Epoch 81 train_nll 0.066696 val_nll -0.050395 box_nll 2.206151 val_mae 0.706301 box_mae 0.003685 n_unstable 0 lr 1e-08
# Epoch 82 train_nll 0.064962 val_nll -0.051184 box_nll 2.202747 val_mae 0.709084 box_mae 0.003696 n_unstable 0 lr 1e-08
# Epoch 83 train_nll 0.063294 val_nll -0.051606 box_nll 2.196443 val_mae 0.710995 box_mae 0.003711 n_unstable 0 lr 1e-08
# Epoch 84 train_nll 0.061448 val_nll -0.053814 box_nll 2.209325 val_mae 0.708783 box_mae 0.003698 n_unstable 0 lr 1e-08
# Epoch 85 train_nll 0.059801 val_nll -0.055464 box_nll 2.211477 val_mae 0.707857 box_mae 0.003691 n_unstable 0 lr 1e-08
# Epoch 86 train_nll 0.058038 val_nll -0.058881 box_nll 2.211787 val_mae 0.708450 box_mae 0.003698 n_unstable 0 lr 1e-08
# Epoch 87 train_nll 0.056445 val_nll -0.062677 box_nll 2.223631 val_mae 0.707143 box_mae 0.003688 n_unstable 0 lr 1e-08
# Epoch 88 train_nll 0.054578 val_nll -0.064527 box_nll 2.211622 val_mae 0.708769 box_mae 0.003704 n_unstable 0 lr 1e-08
# Epoch 89 train_nll 0.053001 val_nll -0.062239 box_nll 2.227878 val_mae 0.707017 box_mae 0.003689 n_unstable 0 lr 1e-08
# Epoch 90 train_nll 0.051183 val_nll -0.067086 box_nll 2.244384 val_mae 0.704462 box_mae 0.003676 n_unstable 0 lr 1e-08
# Epoch 91 train_nll 0.049411 val_nll -0.068180 box_nll 2.245763 val_mae 0.704295 box_mae 0.003668 n_unstable 0 lr 1e-08
# Epoch 92 train_nll 0.047727 val_nll -0.071265 box_nll 2.240395 val_mae 0.706837 box_mae 0.003686 n_unstable 0 lr 1e-08
# Epoch 93 train_nll 0.046091 val_nll -0.069026 box_nll 2.239327 val_mae 0.706962 box_mae 0.003689 n_unstable 0 lr 1e-08
# Epoch 94 train_nll 0.044381 val_nll -0.070923 box_nll 2.263240 val_mae 0.703193 box_mae 0.003662 n_unstable 0 lr 1e-08
# Epoch 95 train_nll 0.042598 val_nll -0.071146 box_nll 2.264041 val_mae 0.703367 box_mae 0.003663 n_unstable 0 lr 1e-08
# Epoch 96 train_nll 0.040934 val_nll -0.072496 box_nll 2.262982 val_mae 0.703879 box_mae 0.003672 n_unstable 0 lr 1e-08
# Epoch 97 train_nll 0.039169 val_nll -0.077095 box_nll 2.262785 val_mae 0.704549 box_mae 0.003671 n_unstable 0 lr 1e-08
# Epoch 98 train_nll 0.037472 val_nll -0.076571 box_nll 2.281938 val_mae 0.702405 box_mae 0.003658 n_unstable 0 lr 1e-08

# %% [markdown]
# ### Run the model in box mode and make some plots

# %%
model = nn.Sequential(
        nn.Linear(9, 4902),
        #nn.BatchNorm1d(4902),
        #nn.LeakyReLU(),
        LinearNormalGamma(4902, 3))

model.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=9, out_features=4902, bias=True)
#   (1): LinearNormalGamma(
#     (linear): Linear(in_features=4902, out_features=12, bias=True)
#   )
# )

# %%
checkpoint = torch.load(
    "gecko/mlp.pt",
    map_location=lambda storage, loc: storage
)

model.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
val_loss = []
_in_array = torch.from_numpy(val_in_array).float()#.to(device).float()

model.eval()
with torch.no_grad():
    # set up array for saving predicted results
    pred_array = np.empty((val_in_array.shape[0], num_timesteps-start_time, len(out_col_idx)))
    var_pred_array = np.empty((val_in_array.shape[0], num_timesteps-start_time, len(out_col_idx)))

    # use initial condition @ t = start_time and get the first prediction
    gamma, v, alpha, beta = model(_in_array[:, start_time, :].to(device))
    pred_array[:, 0, :] = gamma.cpu().numpy()
    var_pred_array[:, 0, :] = np.sqrt(beta.cpu().numpy() / (v.cpu().numpy() * (alpha.cpu().numpy() - 1)))
    loss = torch.nn.functional.l1_loss(_in_array[:, start_time + 1, out_col_idx], gamma.cpu()).item()
    val_loss.append(loss)

    # use the first prediction to get the next, and so on for num_timesteps
    for k, i in enumerate(range(start_time + 1, num_timesteps)): 
        new_input = _in_array[:, i, :]
        new_input[:, out_col_idx] = gamma.cpu()
        gamma, v, alpha, beta = model(new_input.to(device))
        pred_array[:, k+1, :] = gamma.cpu().numpy()
        var_pred_array[:, k+1, :] = np.sqrt(beta.cpu().numpy() / (v.cpu().numpy() * (alpha.cpu().numpy() - 1)))
        if i < (num_timesteps-1):
            loss = torch.nn.functional.l1_loss(_in_array[:, i+1, out_col_idx], gamma.cpu()).item()
            val_loss.append(loss)

# %%
idx = transformed_data["val_out"].index
start_time_units = sorted(list(set([x[0] for x in idx])))[start_time]
start_time_condition = [(x[0] >= start_time_units) for x in idx]
idx = transformed_data["val_out"][start_time_condition].index

raw_box_preds = pd.DataFrame(
    data=pred_array.reshape(-1, len(output_vars)),
    columns=output_vars, 
    index=idx
)

raw_box_vars = pd.DataFrame(
    data=var_pred_array.reshape(-1, len(output_vars)),
    columns=output_vars, 
    index=idx
)

# inverse transform 
truth, preds = inv_transform_preds(
    raw_preds=raw_box_preds,
    truth=data['val_out'][start_time_condition],
    y_scaler=y_scaler,
    log_trans_cols=log_trans_cols,
    tendency_cols=tendency_cols)

_, pred_vars = inv_transform_preds(
    raw_preds=raw_box_vars,
    truth=data['val_out'][start_time_condition],
    y_scaler=y_scaler,
    log_trans_cols=log_trans_cols,
    tendency_cols=tendency_cols)

# %%
for col in output_vars:
    preds[col + "_var"] = pred_vars[col].copy()

# %%
def plot_ensemble(truth, preds, output_path, output_vars, species, model_name, fontsize = 8, n_stds = 4):
    """ Plot ensemble members, ensemble mean, and truth from 3 randomly selected experiments.
    Args:
        truth: Validation dataframe for selected experiments
        preds: Validation dataframe of emulated results for selected experiments
        output_path: Path to save output
        species: Species (from config) used for labeling
        model_name: Model Name (used for labeling)
    """
    times, ids = zip(*list(preds.index))
    preds["Time [s]"] = times
    preds["id"] = ids
    preds = preds.reset_index(drop = True)
    
    times, ids = zip(*list(truth.index))
    truth["Time [s]"] = times
    truth["id"] = ids
    truth = truth.reset_index(drop = True)
    
    preds["member"] = 0
    truth["member"] = 0
    
    all_exps = truth['id'].unique()
    exps = ["Exp1606", "Exp1622", "Exp1696"] #np.random.choice(all_exps, 3, replace=False)
    color = ['darkred', 'darkblue', 'darkgreen']
    mean_ensemble = preds.groupby(['Time [s]', 'id']).mean()[output_vars]
    mean_vars = preds.groupby(['Time [s]', 'id']).mean()[[x + "_var" for x in output_vars]]
    
    #'upgreek'
    single_column_width = 7.5
    
    #matplotlib.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}', r'\usepackage{amssymb}', r'\usepackage{upgreek}']
    matplotlib.rc('xtick', labelsize=fontsize) 
    matplotlib.rc('ytick', labelsize=fontsize)
    fig, axes = plt.subplots(len(output_vars), 3, figsize=(single_column_width, single_column_width / 1.61803398875), 
                             sharex='col', sharey='row',
                             gridspec_kw={'hspace': 0.0, 'wspace': 0.0}, dpi=300)
    fig.set_size_inches(single_column_width, single_column_width / 1.61803398875)
    
    #fig.suptitle('Ensemble Runs - {} - {}'.format(species, model_name), fontsize=10)
    t_sub = truth[truth['member'] == 0]
    if t_sub.shape[0] == 0:
        t_sub = truth[truth['member'] == 0].drop_duplicates()

    times = [x / 3600.0 for x in preds["Time [s]"].unique()]
    ylabels = [r'Precursor ($\mu$g/m$^3$)', r'Gas ($\mu$g/m$^3$)', r'Aerosol ($\mu$g/m$^3$)']
    
    for i, exp in enumerate(exps):
        for j, var in enumerate(output_vars):
            #t_sub.to_csv(join(output_path, 'plots/tsubt.csv'))
            if j == 0:
                axes[j, i].set_title(exp, fontsize=fontsize)
            if i == 0:
                axes[j, i].set_ylabel(ylabels[j], fontsize=fontsize)
            for member in preds['member'].unique():
                p = preds.loc[preds['member'] == member]
                p_sub = p.loc[p['id'] == exp, var].values
                if member == 0:
                    axes[j, i].plot(times, p_sub, linewidth=0.3, color=color[j], label='Member', zorder = 1)
                else:
                    axes[j, i].plot(times, p_sub, linewidth=0.3, color=color[j], label='', alpha = 0.5, zorder = 1)
            m = mean_ensemble.loc[mean_ensemble.index.get_level_values('id') == exp, var].values
            m_var = mean_vars.loc[mean_ensemble.index.get_level_values('id') == exp, var + "_var"].values
            axes[j, i].plot(times, m, color=color[j], linewidth=3, label='Mean', zorder = 2)
            axes[j, i].tick_params(labelsize=fontsize)
            axes[j, i].set_ylim((-0.05, 0.07))
            
            t = t_sub.loc[t_sub['id'] == exp, var].values
            axes[j, i].plot(times, t, linestyle='--', color='k', linewidth=3, label='True', zorder = 3)
            
            for k in np.linspace(0, n_stds, 4):
                axes[j, i].fill_between(
                    times, (m - k * m_var), (m + k * m_var),
                    alpha=0.3,
                    edgecolor=None,
                    facecolor='#00aeef',
                    linewidth=0,
                    zorder=1)
            
        axes[j, i].set_xlabel("Time (hr)", fontsize=fontsize)
    for i in range(3):
        axes[0, i].legend(loc = 'best', fontsize=fontsize)
        #axes[0, i].set_yticks([0.0, 0.02, 0.04])
        
    axes[2, 0].set_xticks([0, 24, 48, 72, 96, 120])
    axes[2, 1].set_xticks([0, 24, 48, 72, 96, 120])
    axes[2, 2].set_xticks([0, 24, 48, 72, 96, 120])
        
    plt.tight_layout()
    plt.show()
    #plt.savefig(model_name, bbox_inches='tight')
    #plt.savefig(join(output_path, 'plots', f'{species}_{model_name}_ensemble.png'), bbox_inches='tight')

# %%
plot_ensemble(truth, preds, output_path, output_vars, species, "MLP", fontsize = 8)
